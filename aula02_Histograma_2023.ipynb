# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoSald/Processamento_digital_de_Imagens/blob/master/aula02_Histograma_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 # importando a biblioteca OpenCv
import numpy as np
from matplotlib import pyplot as plt

# %%
# Leitura da imagem com a função imread()

imagem = cv2.imread('Fig0316.tif')

print('Largura em pixels: ', end='')
print(imagem.shape[1]) #largura da imagem

print('Altura em pixels: ', end='')
print(imagem.shape[0]) #altura da imagem

print('Qtde de canais: ', end='')
print(imagem.shape[2])
# Out:
# Largura em pixels: 500
# Altura em pixels: 500
# Qtde de canais: 3

# %%
imagem.shape
# Out:
# (500, 500, 3)

# %% [markdown]
# https://docs.opencv.org/4.x/d5/daf/tutorial_py_histogram_equalization.

# %%
print(imagem)
# Out:
# [[[ 91  91  91]
#   [ 91  91  91]
#   [ 91  91  91]
#   ...
#   [107 107 107]
#   [107 107 107]
#   [105 105 105]]
#
#  [[ 91  91  91]
#   [ 91  91  91]
#   [ 91  91  91]
#   ...
#   [106 106 106]
#   [106 106 106]
#   [104 104 104]]
#
#  [[ 91  91  91]
#   [ 91  91  91]
#   [ 91  91  91]
#   ...
#   [103 103 103]
#   [103 103 103]
#   [101 101 101]]
#
#  ...
#
#  [[ 96  96  96]
#   [ 91  91  91]
#   [ 91  91  91]
#   ...
#   [122 122 122]
#   [121 121 121]
#   [121 121 121]]
#
#  [[ 97  97  97]
#   [ 94  94  94]
#   [ 91  91  91]
#   ...
#   [121 121 121]
#   [120 120 120]
#   [119 119 119]]
#
#  [[ 98  98  98]
#   [ 96  96  96]
#   [ 91  91  91]
#   ...
#   [120 120 120]
#   [120 120 120]
#   [117 117 117]]]

# %%
# Equalização adaptativa de histograma

# %% [markdown]
# https://docs.opencv.org/4.x/d5/daf/tutorial_py_histogram_equalization.html

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

im1 = cv2.imread('Fig0316.tif')

#transformando o RGB em escalas de cinza
img = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)

#operação de equalização do histograma:
h_eq = cv2.equalizeHist(img)

plt.figure()
plt.title("Histograma Original")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(img.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
plt.figure()

plt.title("Histograma Equalizado")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(h_eq.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
cv2.waitKey(0)

figure, axarr = plt.subplots(1,2, figsize=(20,20))
axarr[0].imshow(im1, cmap='gray')
axarr[1].imshow(h_eq, cmap='gray')

# %%
print(img)
# Out:
# [[ 91  91  91 ... 107 107 105]
#  [ 91  91  91 ... 106 106 104]
#  [ 91  91  91 ... 103 103 101]
#  ...
#  [ 96  91  91 ... 122 121 121]
#  [ 97  94  91 ... 121 120 119]
#  [ 98  96  91 ... 120 120 117]]

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
##EXEMPLO QUE NAO FUNCIONOU TÃO BEM QUANTO O EXEMPLO DE CIMA
im1 = cv2.imread('Fig0304.tif')

#transformando o RGB em escalas de cinza
img = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)

#operação de equalização do histograma:
h_eq = cv2.equalizeHist(img)

plt.figure()
plt.title("Histograma Original")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(img.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
plt.figure()

plt.title("Histograma Equalizado")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(h_eq.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
cv2.waitKey(0)

figure, axarr = plt.subplots(1,2, figsize=(20,20))
axarr[0].imshow(im1, cmap='gray')
axarr[1].imshow(h_eq, cmap='gray')

# %%
#melhorando o histograma com o código abaixo

# %%
import numpy as np
import cv2 as cv
##img = cv.imread('tsukuba_l.png',0)
# create a CLAHE object (Arguments are optional).
clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
cl1 = clahe.apply(img)
#cv.imwrite('clahe_2.jpg',cl1)

plt.figure()
plt.title("Histograma Original")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(h_eq.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
plt.figure()
plt.title("Histograma Equalizado")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(cl1.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
cv2.waitKey(0)

figure, axarr = plt.subplots(1,2, figsize=(20,20))
axarr[0].imshow(img, cmap='gray')
axarr[1].imshow(cl1, cmap='gray')
